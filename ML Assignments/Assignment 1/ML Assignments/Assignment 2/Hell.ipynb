# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
akshit= '\u0905\u0915\u094D\u0937\u093F\u0924'  

print(akshit)
# Out:
# अक्षित

# %%
#Data collection 
v=  pd.read_csv("temperatures.csv")

# %%
v.head()
# Out:
#    YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP    OCT  \
# 0  1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47  29.97
# 1  1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80  29.12
# 2  1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85  29.04
# 3  1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04  29.20
# 4  1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12  30.67
#
#      NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 0  27.31  24.49   28.96    23.27    31.46    31.27    27.25
# 1  26.31  24.04   29.22    25.75    31.76    31.09    26.49
# 2  26.08  23.65   28.47    24.24    30.71    30.92    26.26
# 3  26.36  23.63   28.49    23.62    30.95    30.66    26.40
# 4  27.52  23.82   28.30    22.25    30.00    31.33    26.57

# %%
v.tail()
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 112  30.27  27.83  25.37   29.81    25.58    32.58    31.33    27.83
# 113  30.29  28.05  25.08   29.72    24.90    31.82    32.00    27.81
# 114  31.04  28.10  25.67   29.90    25.74    31.68    31.87    28.27
# 115  31.98  30.11  28.01   31.63    28.33    34.57    32.28    30.03
# 116  32.29  29.60  27.18   31.42    27.95    34.13    32.41    29.69

# %%
v.describe()
# Out:
#               YEAR         JAN         FEB         MAR         APR  \
# count   117.000000  117.000000  117.000000  117.000000  117.000000
# mean   1959.000000   23.687436   25.597863   29.085983   31.975812
# std      33.919021    0.834588    1.150757    1.068451    0.889478
# min    1901.000000   22.000000   22.830000   26.680000   30.010000
# 25%    1930.000000   23.100000   24.780000   28.370000   31.460000
# 50%    1959.000000   23.680000   25.480000   29.040000   31.950000
# 75%    1988.000000   24.180000   26.310000   29.610000   32.420000
# max    2017.000000   26.940000   29.720000   32.620000   35.380000
#
#               MAY         JUN         JUL         AUG         SEP         OCT  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean    33.565299   32.774274   31.035897   30.507692   30.486752   29.766581
# std      0.724905    0.633132    0.468818    0.476312    0.544295    0.705492
# ...

# %%
v.info
# Out:
# <bound method DataFrame.info of      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 0    1901  22.40  24.14  29.07  31.91  33.41  33.18  31.21  30.39  30.47
# 1    1902  24.93  26.58  29.77  31.78  33.73  32.91  30.92  30.73  29.80
# 2    1903  23.44  25.03  27.83  31.39  32.91  33.00  31.34  29.98  29.85
# 3    1904  22.50  24.73  28.21  32.02  32.64  32.07  30.36  30.09  30.04
# 4    1905  22.00  22.83  26.68  30.01  33.32  33.25  31.44  30.68  30.12
# ..    ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
# ...

# %%
v.corr()
# Out:
#                  YEAR       JAN       FEB       MAR       APR       MAY  \
# YEAR         1.000000  0.575499  0.647066  0.553886  0.540662  0.407648
# JAN          0.575499  1.000000  0.647017  0.457081  0.594674  0.365236
# FEB          0.647066  0.647017  1.000000  0.589088  0.548803  0.377722
# MAR          0.553886  0.457081  0.589088  1.000000  0.618621  0.387756
# APR          0.540662  0.594674  0.548803  0.618621  1.000000  0.563317
# MAY          0.407648  0.365236  0.377722  0.387756  0.563317  1.000000
# JUN          0.371840  0.292855  0.341302  0.228349  0.299866  0.274521
# JUL          0.478512  0.339337  0.418956  0.232647  0.286052  0.299072
# AUG          0.654138  0.459944  0.503188  0.382344  0.490668  0.473171
# SEP          0.664008  0.499764  0.472755  0.370066  0.437970  0.347289
# OCT          0.589073  0.480695  0.466916  0.312226  0.473873  0.468993
# NOV          0.697887  0.526615  0.519595  0.498202  0.538037  0.482822
# ...

# %%
monthly_columns = ['JAN', 'FEB', 'MAR', 'APR', 'MAY', 'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC']
monthly_data = v[monthly_columns]

# %%
# Standardizing the data before applying PCA
scaler = StandardScaler()
monthly_data_scaled = scaler.fit_transform(monthly_data)

# Applying PCA
pca = PCA(n_components=1)
monthly_pca = pca.fit_transform(monthly_data_scaled)

# Adding the PCA result as a new column to the original dataframe
v['MONTHLY_PCA'] = monthly_pca

# %%
v.corr()["MONTHLY_PCA"].sort_values(ascending=False)
# Out:
# MONTHLY_PCA    1.000000
# ANNUAL         0.988512
# OCT-DEC        0.917755
# JUN-SEP        0.859390
# NOV            0.851729
# DEC            0.848124
# OCT            0.812615
# MAR-MAY        0.810007
# JAN-FEB        0.802486
# AUG            0.798449
# YEAR           0.796998
# SEP            0.772477
# FEB            0.743128
# APR            0.732701
# JAN            0.718147
# JUL            0.653251
# MAR            0.633258
# MAY            0.617345
# JUN            0.538081
# Name: MONTHLY_PCA, dtype: float64

# %%
# Step 1: Get the sorted correlation values for "MONTHLY_PCA"
sorted_corr = v.corr()["MONTHLY_PCA"].sort_values(ascending=False)

# Step 2: Store the sorted correlation values in an array
sorted_corr_array = sorted_corr.values

# Step 3: Retrieve the first index feature
first_feature = sorted_corr.index[0]

# Step 4: Remove the first index feature from the array
sorted_corr_array_without_first = sorted_corr_array[1:]

# Retrieve the names of the next features (second, third, fourth)
second_feature = sorted_corr.index[1]
third_feature = sorted_corr.index[2]
fourth_feature = sorted_corr.index[3]
fifth_feature = sorted_corr.index[4]

# Print the name of the feature that was removed
print("The feature that was removed (first feature):", first_feature)

# Print the whole array after removing the first feature
print("Array after removing the first feature:", sorted_corr_array_without_first)

# Print the names of the next features
print("The second feature after removal:", second_feature)
print("The third feature after removal:", third_feature)
print("The fourth feature after removal:", fourth_feature)
# Out:
# The feature that was removed (first feature): MONTHLY_PCA
# Array after removing the first feature: [0.98851201 0.91775529 0.85939033 0.85172859 0.8481241  0.81261481
#  0.81000711 0.80248568 0.79844945 0.7969981  0.77247689 0.74312807
#  0.73270095 0.7181471  0.65325146 0.63325823 0.61734523 0.53808076]
# The second feature after removal: ANNUAL
# The third feature after removal: OCT-DEC
# The fourth feature after removal: JUN-SEP

# %%
v[[second_feature, 'MONTHLY_PCA']].head()
# Out:
#    ANNUAL  MONTHLY_PCA
# 0   28.96    -0.689853
# 1   29.22    -0.428795
# 2   28.47    -2.710225
# 3   28.49    -3.380420
# 4   28.30    -2.093893

# %%
plt.scatter(v[second_feature], v['MONTHLY_PCA'], label='Monthly PCA',color='red',marker='o');
plt.xlabel("Highly correlated feature with Montly pca values "); 
plt.ylabel("PCA Combined Temperature Feature");
plt.title("Year vs Monthly PCA Temperature Feature");
plt.grid(True)
plt.show()

# %%
x = v[[second_feature]]
y = v[['MONTHLY_PCA']]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# Lists to store SSE values
train_sse = []
test_sse = []
train_sizes = np.arange(0.1, 1.0, 0.1)  # Training sizes from 0.1 to 0.9

# Loop to compute SSE for different training sizes
for tr_size in train_sizes:
    x_train, x_test, y_train, y_test = train_test_split(x, y, train_size=tr_size, random_state=1)
    
    mod = LinearRegression()
    mod.fit(x_train, y_train)
    
    pred_train = mod.predict(x_train)
    pred_test = mod.predict(x_test)
    
    tr_sse = np.sum((pred_train - y_train)**2)
    te_sse = np.sum((pred_test - y_test)**2)
    
    train_sse.append(tr_sse)
    test_sse.append(te_sse)

# Convert lists to arrays for analysis
train_sse = np.array(train_sse)
test_sse = np.array(test_sse)

# Compute the ratio of testing error to training error
error_ratio = test_sse / train_sse

# Find the index where the testing error is balanced with training error
# This index is where the error ratio is lowest but still with manageable training error
balanced_index = np.argmin(np.abs(error_ratio - np.min(error_ratio)))

optimal_train_size = train_sizes[balanced_index]

# Plot the SSE against the training size
plt.figure(figsize=(10, 6))
plt.plot(train_sizes, train_sse, 'r-o', label="Training Error")
plt.plot(train_sizes, test_sse, 'b-o', label="Testing Error")
plt.grid(True)
plt.xlabel("Training Size")
plt.ylabel("Sum of Squared Errors (SSE)")
plt.title("Effect of Training Size on Training and Testing Error")
plt.legend()
plt.show()
# Out:
# C:\Users\akshi\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# C:\Users\akshi\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# ...

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=1-optimal_train_size, random_state=1)

# %%
# Check the shapes of the training and testing data
print("x_train.shape:", x_train.shape)
print("x_test.shape:", x_test.shape)
print("y_train.shape:", y_train.shape)
print("y_test.shape:", y_test.shape)
# Out:
# x_train.shape: (105, 1)
# x_test.shape: (12, 1)
# y_train.shape: (105, 1)
# y_test.shape: (12, 1)

# %%
# Fit the Linear Regression model
model_h = LinearRegression()
model_h.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Predict on the training and testing sets
train_predicted = model_h.predict(x_train)
test_predicted = model_h.predict(x_test)

# %%
# Calculate Sum of Squared Errors (SSE) for the training set
train_sse = np.sum((train_predicted - y_train)**2, axis=0)
print("Training SSE:", train_sse)
# Out:
# Training SSE: MONTHLY_PCA    14.854181
# dtype: float64

# %%
# Calculate MAE, MSE, and R² for the training set
mae_train = round(mean_absolute_error(y_train, train_predicted), 2)
mse_train = round(mean_squared_error(y_train, train_predicted), 2)
r2_train = round(r2_score(y_train, train_predicted), 2)

# Print training results
print("Training Mean Absolute Error (MAE):", mae_train)
print("Training Mean Squared Error (MSE):", mse_train)
print("Training R-squared (R²):", r2_train)

# Calculate SSE for the training set
train_sse = np.sum((train_predicted - y_train) ** 2)
print("Training SSE:", train_sse)

# Calculate MAE, MSE, and R² for the testing set
mae_test = round(mean_absolute_error(y_test, test_predicted), 2)
mse_test = round(mean_squared_error(y_test, test_predicted), 2)
r2_test = round(r2_score(y_test, test_predicted), 2)

# Print testing results
print("Testing Mean Absolute Error (MAE):", mae_test)
print("Testing Mean Squared Error (MSE):", mse_test)
print("Testing R-squared (R²):", r2_test)

# Calculate SSE for the testing set
test_sse = np.sum((test_predicted - y_test) ** 2)
print("Testing SSE:", test_sse)
# Out:
# Training Mean Absolute Error (MAE): 0.28
# Training Mean Squared Error (MSE): 0.14
# Training R-squared (R²): 0.98
# Training SSE: MONTHLY_PCA    14.854181
# dtype: float64
# Testing Mean Absolute Error (MAE): 0.32
# Testing Mean Squared Error (MSE): 0.2
# Testing R-squared (R²): 0.92
# Testing SSE: MONTHLY_PCA    2.386925
# dtype: float64
# C:\Users\akshi\AppData\Roaming\Python\Python312\site-packages\numpy\core\fromnumeric.py:86: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)
# ...

# %%
# Plot the results
plt.plot(x_train, train_predicted, c='b')
plt.scatter(x_train, y_train, c='r')
plt.scatter(x_test, y_test, c='g')
plt.legend(["Best Fit Line", "Training Sample", "Testing Samples"])
plt.xlabel("YEAR")
plt.ylabel("PCA Combined Temperature Feature")
plt.title("Linear Regression on PCA Combined Temperature Feature")
plt.show()

# %%
v.corr()["MONTHLY_PCA"].sort_values(ascending=False)
# Out:
# MONTHLY_PCA    1.000000
# ANNUAL         0.988512
# OCT-DEC        0.917755
# JUN-SEP        0.859390
# NOV            0.851729
# DEC            0.848124
# OCT            0.812615
# MAR-MAY        0.810007
# JAN-FEB        0.802486
# AUG            0.798449
# YEAR           0.796998
# SEP            0.772477
# FEB            0.743128
# APR            0.732701
# JAN            0.718147
# JUL            0.653251
# MAR            0.633258
# MAY            0.617345
# JUN            0.538081
# Name: MONTHLY_PCA, dtype: float64

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
features = [third_feature, fourth_feature, fifth_feature]
X = v[features]
y = v['MONTHLY_PCA']

train_sse = []
test_sse = []

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1-optimal_train_size, random_state=42)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_train_pred = model.predict(X_train)
y_test_pred = model.predict(X_test)

# %%
train_mse = mean_squared_error(y_train, y_train_pred)
test_mse = mean_squared_error(y_test, y_test_pred)

# %%
fig = plt.figure(figsize=(12, 6))

# Define the meshgrid for plotting the plane
xx, yy = np.meshgrid(np.linspace(min(X_train[third_feature].min(), X_test[third_feature].min()), 
                                 max(X_train[third_feature].max(), X_test[third_feature].max()), 50),
                     np.linspace(min(X_train[fourth_feature].min(), X_test[fourth_feature].min()), 
                                 max(X_train[fourth_feature].max(), X_test[fourth_feature].max()), 50))

# Calculate the corresponding z values for the plane using the model's coefficients
zz = model.intercept_ + model.coef_[0] * xx + model.coef_[1] * yy

# Combined plot for training and testing data
ax = fig.add_subplot(111, projection='3d')

# Training data
ax.scatter(X_train[third_feature], X_train[fourth_feature], y_train, color='blue', label='Train Actual')
ax.scatter(X_train[third_feature], X_train[fourth_feature], model.predict(X_train), color='red', label='Train Predicted', alpha=0.5)

# Testing data
ax.scatter(X_test[third_feature], X_test[fourth_feature], y_test, color='green', label='Test Actual')
ax.scatter(X_test[third_feature], X_test[fourth_feature], y_test_pred, color='orange', label='Test Predicted', alpha=0.5)

# Plotting the best-fit plane
ax.plot_surface(xx, yy, zz, color='yellow', alpha=0.3, rstride=100, cstride=100)

ax.set_xlabel(third_feature)
ax.set_ylabel(fourth_feature)
ax.set_zlabel('MONTHLY_PCA')
ax.set_title('Combined Training and Testing Data')
ax.legend()

plt.show()
